# %%
import pandas as pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
from pathlib import Path

# Get project root directory dynamically
project_root = Path.cwd()
if not (project_root / 'data').exists():
    project_root = project_root.parent

raw_data_path = project_root / 'data' / 'raw'

# Load all raw datasets
df_1 = pandas.read_csv(raw_data_path / '01_fund_master.csv')
df_2 = pandas.read_csv(raw_data_path / '02_nav_history.csv')
df_3 = pandas.read_csv(raw_data_path / '03_aum_by_fund_house.csv')
df_4 = pandas.read_csv(raw_data_path / '04_monthly_sip_inflows.csv')
df_5 = pandas.read_csv(raw_data_path / '05_category_inflows.csv')
df_6 = pandas.read_csv(raw_data_path / '06_industry_folio_count.csv')
df_7 = pandas.read_csv(raw_data_path / '07_scheme_performance.csv')
df_8 = pandas.read_csv(raw_data_path / '08_investor_transactions.csv')
df_9 = pandas.read_csv(raw_data_path / '09_portfolio_holdings.csv')
df_10 = pandas.read_csv(raw_data_path / '10_benchmark_indices.csv')

print(f"✓ Data loaded from: {raw_data_path}")

# %%
print("Dataframe 1 : Fund Master")
df_1.info()
print("Shape : ", df_1.shape[0])
print("Type : ", df_1.dtypes)
print(df_1.head(5))
# Out:
# Dataframe 1 : Fund Master
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     object
#  2   scheme_name         40 non-null     object
#  3   category            40 non-null     object
#  4   sub_category        40 non-null     object
#  5   plan                40 non-null     object
#  6   launch_date         40 non-null     object
#  7   benchmark           40 non-null     object
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     object
#  13  risk_category       40 non-null     object
#  14  sebi_category_code  40 non-null     object
# ...

# %%
print("Dataframe 2 : NAV History")
df_2.info()

print("Shape : ", df_2.shape[0])
print("Type : ", df_2.dtypes)
print(df_2.head(5))
# Out:
# Dataframe 2 : NAV History
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  object
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ MB
# Shape :  46000
# Type :  amfi_code      int64
# date          object
# nav          float64
# dtype: object
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
print("Dataframe 3 : AUM by Fund House")
df_3.info()
print("Shape : ", df_3.shape[0])    
print("Type : ", df_3.dtypes)
print(df_3.head(5))
# Out:
# Dataframe 3 : AUM by Fund House
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            90 non-null     object
#  1   fund_house      90 non-null     object
#  2   aum_lakh_crore  90 non-null     float64
#  3   aum_crore       90 non-null     int64
#  4   num_schemes     90 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.6+ KB
# Shape :  90
# Type :  date               object
# fund_house         object
# aum_lakh_crore    float64
# aum_crore           int64
# num_schemes         int64
# dtype: object
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# ...

# %%
print("Dataframe 4 : Monthly SIP Inflows")
df_4.info()
print("Shape : ", df_4.shape[0])
print("Type : ", df_4.dtypes)
print(df_4.head(5))
# Out:
# Dataframe 4 : Monthly SIP Inflows
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      48 non-null     object
#  1   sip_inflow_crore           48 non-null     int64
#  2   active_sip_accounts_crore  48 non-null     float64
#  3   new_sip_accounts_lakh      48 non-null     float64
#  4   sip_aum_lakh_crore         48 non-null     float64
#  5   yoy_growth_pct             36 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.4+ KB
# Shape :  48
# Type :  month                         object
# sip_inflow_crore               int64
# active_sip_accounts_crore    float64
# new_sip_accounts_lakh        float64
# sip_aum_lakh_crore           float64
# yoy_growth_pct               float64
# dtype: object
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# ...

# %%
print("Dataframe 5 : Category Inflows")
df_5.info()
print("Shape : ", df_5.shape[0])
print("Type : ", df_5.dtypes)
print(df_5.head(5))
# Out:
# Dataframe 5 : Category Inflows
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             144 non-null    object
#  1   category          144 non-null    object
#  2   net_inflow_crore  144 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 3.5+ KB
# Shape :  144
# Type :  month                object
# category             object
# net_inflow_crore    float64
# dtype: object
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
print("Dataframe 6 : Industry Folio Count")
df_6.info()
print("Shape : ", df_6.shape[0])
print("Type : ", df_6.dtypes)
print(df_6.head(5))
# Out:
# Dataframe 6 : Industry Folio Count
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                21 non-null     object
#  1   total_folios_crore   21 non-null     float64
#  2   equity_folios_crore  21 non-null     float64
#  3   debt_folios_crore    21 non-null     float64
#  4   hybrid_folios_crore  21 non-null     float64
#  5   others_folios_crore  21 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.1+ KB
# Shape :  21
# Type :  month                   object
# total_folios_crore     float64
# equity_folios_crore    float64
# debt_folios_crore      float64
# hybrid_folios_crore    float64
# others_folios_crore    float64
# dtype: object
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# ...

# %%
print("dataframe 7 : Scheme Performance")
df_7.info()
print("Shape : ", df_7.shape[0])
print("Type : ", df_7.dtypes)
print(df_7.head(5))
# Out:
# dataframe 7 : Scheme Performance
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   scheme_name         40 non-null     object
#  2   fund_house          40 non-null     object
#  3   category            40 non-null     object
#  4   plan                40 non-null     object
#  5   return_1yr_pct      40 non-null     float64
#  6   return_3yr_pct      40 non-null     float64
#  7   return_5yr_pct      40 non-null     float64
#  8   benchmark_3yr_pct   40 non-null     float64
#  9   alpha               40 non-null     float64
#  10  beta                40 non-null     float64
#  11  sharpe_ratio        40 non-null     float64
#  12  sortino_ratio       40 non-null     float64
#  13  std_dev_ann_pct     40 non-null     float64
# ...

# %%
print("Dataframe 8 : Investor Transactions")
df_8.info()
print("Shape : ", df_8.shape[0])
print("Type : ", df_8.dtypes)
print(df_8.head(5))
# Out:
# Dataframe 8 : Investor Transactions
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32778 entries, 0 to 32777
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   investor_id         32778 non-null  object
#  1   transaction_date    32778 non-null  object
#  2   amfi_code           32778 non-null  int64
#  3   transaction_type    32778 non-null  object
#  4   amount_inr          32778 non-null  int64
#  5   state               32778 non-null  object
#  6   city                32778 non-null  object
#  7   city_tier           32778 non-null  object
#  8   age_group           32778 non-null  object
#  9   gender              32778 non-null  object
#  10  annual_income_lakh  32778 non-null  float64
#  11  payment_mode        32778 non-null  object
#  12  kyc_status          32778 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 3.3+ MB
# Shape :  32778
# ...

# %%
print("dataframe 9 : Portfolio Holdings")
df_9.info()
print("Shape : ", df_9.shape[0])
print("Type : ", df_9.dtypes)
print(df_9.head(5))
# Out:
# dataframe 9 : Portfolio Holdings
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   amfi_code          322 non-null    int64
#  1   stock_symbol       322 non-null    object
#  2   stock_name         322 non-null    object
#  3   sector             322 non-null    object
#  4   weight_pct         322 non-null    float64
#  5   market_value_cr    322 non-null    float64
#  6   current_price_inr  322 non-null    float64
#  7   portfolio_date     322 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 20.2+ KB
# Shape :  322
# Type :  amfi_code              int64
# stock_symbol          object
# stock_name            object
# sector                object
# weight_pct           float64
# market_value_cr      float64
# current_price_inr    float64
# portfolio_date        object
# dtype: object
# ...

# %%
print("Dataframe 10 : Benchmark Indices")
df_10.info()
print("Shape : ", df_10.shape[0])
print("Type : ", df_10.dtypes)
print(df_10.head(5))
# Out:
# Dataframe 10 : Benchmark Indices
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8050 entries, 0 to 8049
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         8050 non-null   object
#  1   index_name   8050 non-null   object
#  2   close_value  8050 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 188.8+ KB
# Shape :  8050
# Type :  date            object
# index_name      object
# close_value    float64
# dtype: object
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15

# %%
df_1.columns
# Out:
# Index(['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category',
#        'plan', 'launch_date', 'benchmark', 'expense_ratio_pct',
#        'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager',
#        'risk_category', 'sebi_category_code'],
#       dtype='object')

# %%
print(df_1["fund_house"].unique())
# Out:
# ['SBI Mutual Fund' 'HDFC Mutual Fund' 'ICICI Prudential MF'
#  'Nippon India MF' 'Kotak Mahindra MF' 'Axis Mutual Fund'
#  'Aditya Birla Sun Life MF' 'UTI Mutual Fund' 'Mirae Asset MF'
#  'DSP Mutual Fund']

# %%
print(df_1['category'].unique())
# Out:
# ['Equity' 'Debt']

# %%
print(df_1['category'].unique())

# %%
print(df_1["risk_category"].unique())
# Out:
# ['Moderate' 'Very High' 'Low' 'High' 'Moderately High']

# %%
print(df_1["sub_category"].unique())
# Out:
# ['Large Cap' 'Small Cap' 'Gilt' 'Mid Cap' 'Short Duration' 'Value'
#  'Liquid' 'Index/ETF' 'Flexi Cap' 'Index' 'Large & Mid Cap' 'ELSS']

# %%
print(df_1["amfi_code"].unique())
# Out:
# [119551 119552 119598 119599 119120 100016 125497 100033 125498 100025
#  120503 120504 120505 120506 120507 118632 118633 118634 118635 118636
#  120841 120842 120843 120844 119092 119093 119094 119095 101206 101207
#  101208 102885 102886 102887 148567 148568 148569 149322 149323 149324]

# %%
df_1[["fund_house", "category", "sub_category", "risk_category", "amfi_code"]]
# Out:
#                   fund_house category     sub_category    risk_category  \
# 0            SBI Mutual Fund   Equity        Large Cap         Moderate
# 1            SBI Mutual Fund   Equity        Large Cap         Moderate
# 2            SBI Mutual Fund   Equity        Small Cap        Very High
# 3            SBI Mutual Fund   Equity        Small Cap        Very High
# 4            SBI Mutual Fund     Debt             Gilt              Low
# 5           HDFC Mutual Fund   Equity        Large Cap         Moderate
# 6           HDFC Mutual Fund   Equity        Large Cap         Moderate
# 7           HDFC Mutual Fund   Equity          Mid Cap             High
# 8           HDFC Mutual Fund   Equity          Mid Cap             High
# 9           HDFC Mutual Fund     Debt   Short Duration              Low
# 10       ICICI Prudential MF   Equity        Large Cap         Moderate
# 11       ICICI Prudential MF   Equity        Large Cap         Moderate
# ...

# %%
df_2.columns
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='object')

# %%
df_2['amfi_code'].unique()
# Out:
# array([119551, 119552, 119598, 119599, 119120, 100016, 125497, 100033,
#        125498, 100025, 120503, 120504, 120505, 120506, 120507, 118632,
#        118633, 118634, 118635, 118636, 120841, 120842, 120843, 120844,
#        119092, 119093, 119094, 119095, 101206, 101207, 101208, 102885,
#        102886, 102887, 148567, 148568, 148569, 149322, 149323, 149324],
#       dtype=int64)

# %%
print(df_1['amfi_code'].isin(df_2['amfi_code']).all())
# Out:
# True

# %%
df_1.describe()
# Out:
#            amfi_code  expense_ratio_pct  exit_load_pct  min_sip_amount  \
# count      40.000000          40.000000      40.000000            40.0
# mean   120247.000000           1.237000       0.812500           500.0
# std     14534.998667           0.386584       0.387091             0.0
# min    100016.000000           0.550000       0.000000           500.0
# 25%    118632.750000           0.787500       1.000000           500.0
# 50%    119551.500000           1.425000       1.000000           500.0
# 75%    120842.250000           1.540000       1.000000           500.0
# max    149324.000000           1.640000       1.000000           500.0
#
#        min_lumpsum_amount
# count           40.000000
# mean          1277.500000
# std           1082.847031
# min            100.000000
# 25%           1000.000000
# 50%           1000.000000
# 75%           1000.000000
# max           5000.000000

# %%
df_2.describe()
# Out:
#            amfi_code           nav
# count   46000.000000  46000.000000
# mean   120247.000000    269.570265
# std     14352.317221    577.187060
# min    100016.000000     26.136600
# 25%    118632.750000     69.170425
# 50%    119551.500000    122.732150
# 75%    120842.250000    260.338675
# max    149324.000000   4268.549700

# %%
df_3.describe()
# Out:
#        aum_lakh_crore     aum_crore  num_schemes
# count       90.000000  9.000000e+01    90.000000
# mean         4.352889  4.352889e+05   152.200000
# std          2.734328  2.734328e+05    52.108832
# min          1.050000  1.050000e+05    56.000000
# 25%          2.525000  2.525000e+05    95.000000
# 50%          3.450000  3.450000e+05   172.500000
# 75%          5.675000  5.675000e+05   195.000000
# max         12.500000  1.250000e+06   216.000000

# %%
df_4.describe()
# Out:
#        sip_inflow_crore  active_sip_accounts_crore  new_sip_accounts_lakh  \
# count         48.000000                  48.000000              48.000000
# mean       19577.520833                   7.189583               9.893750
# std         6354.329621                   1.271457               5.370745
# min        11438.000000                   4.910000               7.500000
# 25%        13658.500000                   6.110000               8.775000
# 50%        18224.000000                   7.150000               9.200000
# 75%        25944.250000                   8.300000               9.562500
# max        31002.000000                   9.350000              46.000000
#
#        sip_aum_lakh_crore  yoy_growth_pct
# count           48.000000       36.000000
# mean             8.632083       31.456944
# std              3.613579       11.768190
# min              4.800000       15.800000
# 25%              5.790000       20.245000
# 50%              7.265000       28.295000
# ...
