# %%
import pandas as pd

# %%
from pathlib import Path

# Get project root directory dynamically
project_root = Path.cwd()
if not (project_root / 'data').exists():
    project_root = project_root.parent

raw_data_path = project_root / 'data' / 'raw'
processed_data_path = project_root / 'data' / 'processed'
processed_data_path.mkdir(parents=True, exist_ok=True)

# %%
df_1 = pd.read_csv(raw_data_path / '01_fund_master.csv')
df_2 = pd.read_csv(raw_data_path / '02_nav_history.csv')
df_3 = pd.read_csv(raw_data_path / '03_aum_by_fund_house.csv')
df_4 = pd.read_csv(raw_data_path / '04_monthly_sip_inflows.csv')
df_5 = pd.read_csv(raw_data_path / '05_category_inflows.csv')
df_6 = pd.read_csv(raw_data_path / '06_industry_folio_count.csv')
df_7 = pd.read_csv(raw_data_path / '07_scheme_performance.csv')
df_8 = pd.read_csv(raw_data_path / '08_investor_transactions.csv')
df_9 = pd.read_csv(raw_data_path / '09_portfolio_holdings.csv')
df_10 = pd.read_csv(raw_data_path / '10_benchmark_indices.csv')

print(f"✓ Loaded data from: {raw_data_path}")

# %%
df_1
# Out:
#     amfi_code                fund_house  \
# 0      119551           SBI Mutual Fund
# 1      119552           SBI Mutual Fund
# 2      119598           SBI Mutual Fund
# 3      119599           SBI Mutual Fund
# 4      119120           SBI Mutual Fund
# 5      100016          HDFC Mutual Fund
# 6      125497          HDFC Mutual Fund
# 7      100033          HDFC Mutual Fund
# 8      125498          HDFC Mutual Fund
# 9      100025          HDFC Mutual Fund
# 10     120503       ICICI Prudential MF
# 11     120504       ICICI Prudential MF
# 12     120505       ICICI Prudential MF
# 13     120506       ICICI Prudential MF
# 14     120507       ICICI Prudential MF
# 15     118632           Nippon India MF
# 16     118633           Nippon India MF
# 17     118634           Nippon India MF
# 18     118635           Nippon India MF
# 19     118636           Nippon India MF
# 20     120841         Kotak Mahindra MF
# 21     120842         Kotak Mahindra MF
# ...

# %%
df_2['date'] = pd.to_datetime(df_2['date'], format='%Y-%m-%d')

# %%
df_2.sort_values(by=['date','amfi_code'], inplace=True)

# %%
df_2
# Out:
#        amfi_code       date       nav
# 5750      100016 2022-01-03  520.4608
# 10350     100025 2022-01-03   26.3169
# 8050      100033 2022-01-03  107.3758
# 32200     101206 2022-01-03  305.0996
# 33350     101207 2022-01-03   38.5736
# ...          ...        ...       ...
# 41399     148568 2026-05-29  205.4510
# 42549     148569 2026-05-29   97.7435
# 43699     149322 2026-05-29  606.2349
# 44849     149323 2026-05-29  245.3651
# 45999     149324 2026-05-29  279.7511
#
# [46000 rows x 3 columns]

# %%
df_2[df_2['nav'] <0]
df_2[df_2['nav'] == 0]
# Out:
# Empty DataFrame
# Columns: [amfi_code, date, nav]
# Index: []

# %%
df_2.duplicated().sum()
# Out:
# 0

# %%
new_type=pd.get_dummies(df_8['transaction_type'], prefix='transaction_type')

# %%
df_8.drop(['transaction_type'], axis=1, inplace=True)

# %%
df_8=df_8.join(new_type)

# %%
df_8
# Out:
#       investor_id transaction_date  amfi_code  amount_inr           state  \
# 0       INV003054       2024-01-01     119092        1834       Telangana
# 1       INV002952       2024-01-01     148567      392882          Punjab
# 2       INV003420       2024-01-01     118636         912         Haryana
# 3       INV003436       2024-01-01     118634        1102     Maharashtra
# 4       INV004691       2024-01-01     119094        8682           Delhi
# ...           ...              ...        ...         ...             ...
# 32773   INV003340       2025-05-30     101207      168029  Madhya Pradesh
# 32774   INV001838       2025-05-30     119093        2175   Uttar Pradesh
# 32775   INV000074       2025-05-30     120504       25998       Rajasthan
# 32776   INV002929       2025-05-30     148568         459     West Bengal
# 32777   INV001852       2025-05-30     118633      226721       Telangana
#
#             city city_tier age_group  gender  annual_income_lakh payment_mode  \
# ...

# %%
df_8[df_8['amount_inr']<0]
df_8[df_8['amount_inr']==0]
# Out:
# Empty DataFrame
# Columns: [investor_id, transaction_date, amfi_code, amount_inr, state, city, city_tier, age_group, gender, annual_income_lakh, payment_mode, kyc_status, transaction_type_Lumpsum, transaction_type_Redemption, transaction_type_SIP]
# Index: []

# %%
df_8['transaction_date'] = pd.to_datetime(df_8['transaction_date'], format='%Y-%m-%d')

# %%
df_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32778 entries, 0 to 32777
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   investor_id                  32778 non-null  object
#  1   transaction_date             32778 non-null  datetime64[ns]
#  2   amfi_code                    32778 non-null  int64
#  3   amount_inr                   32778 non-null  int64
#  4   state                        32778 non-null  object
#  5   city                         32778 non-null  object
#  6   city_tier                    32778 non-null  object
#  7   age_group                    32778 non-null  object
#  8   gender                       32778 non-null  object
#  9   annual_income_lakh           32778 non-null  float64
#  10  payment_mode                 32778 non-null  object
#  11  kyc_status                   32778 non-null  object
# ...

# %%
df_8['kyc_status'].unique()
# Out:
# array(['Verified', 'Pending'], dtype=object)

# %%
df_8.sort_values(by=['transaction_date','amfi_code'], inplace=True)

# %%
df_7
# Out:
#     amfi_code                                        scheme_name  \
# 0      119551          SBI Bluechip Fund - Regular Plan - Growth
# 1      119552           SBI Bluechip Fund - Direct Plan - Growth
# 2      119598         SBI Small Cap Fund - Regular Plan - Growth
# 3      119599          SBI Small Cap Fund - Direct Plan - Growth
# 4      119120       SBI Magnum Gilt Fund - Regular Plan - Growth
# 5      100016          HDFC Top 100 Fund - Regular Plan - Growth
# 6      125497           HDFC Top 100 Fund - Direct Plan - Growth
# 7      100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 8      125498  HDFC Mid-Cap Opportunities Fund - Direct - Growth
# 9      100025       HDFC Short Term Debt Fund - Regular - Growth
# 10     120503         ICICI Pru Bluechip Fund - Regular - Growth
# 11     120504          ICICI Pru Bluechip Fund - Direct - Growth
# 12     120505           ICICI Pru Midcap Fund - Regular - Growth
# ...

# %%
df_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   scheme_name         40 non-null     object
#  2   fund_house          40 non-null     object
#  3   category            40 non-null     object
#  4   plan                40 non-null     object
#  5   return_1yr_pct      40 non-null     float64
#  6   return_3yr_pct      40 non-null     float64
#  7   return_5yr_pct      40 non-null     float64
#  8   benchmark_3yr_pct   40 non-null     float64
#  9   alpha               40 non-null     float64
#  10  beta                40 non-null     float64
#  11  sharpe_ratio        40 non-null     float64
#  12  sortino_ratio       40 non-null     float64
#  13  std_dev_ann_pct     40 non-null     float64
#  14  max_drawdown_pct    40 non-null     float64
# ...

# %%
df_7['expense_ratio_pct'].max(),df_7['expense_ratio_pct'].min()
# Out:
# (1.64, 0.55)

# %%
df_7['sharpe_ratio'].max(),df_7['sharpe_ratio'].min()
# Out:
# (7.68, 0.8)

# %%
df_1['launch_date']= pd.to_datetime(df_1['launch_date'], format='%Y-%m-%d')

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46000 entries, 5750 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  datetime64[ns]
#  2   nav        46000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.4 MB

# %%
df_3['date'] = pd.to_datetime(df_3['date'], format='%Y-%m-%d')

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   month                      48 non-null     object
#  1   sip_inflow_crore           48 non-null     int64
#  2   active_sip_accounts_crore  48 non-null     float64
#  3   new_sip_accounts_lakh      48 non-null     float64
#  4   sip_aum_lakh_crore         48 non-null     float64
#  5   yoy_growth_pct             36 non-null     float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df_4['yoy_growth_pct'].fillna(0, inplace=True)
# Out:
# C:\Users\JAY MISTRY\AppData\Local\Temp\ipykernel_3180\309821498.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_4['yoy_growth_pct'].fillna(0, inplace=True)

# %%
df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             144 non-null    object
#  1   category          144 non-null    object
#  2   net_inflow_crore  144 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 3.5+ KB

# %%
df_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                21 non-null     object
#  1   total_folios_crore   21 non-null     float64
#  2   equity_folios_crore  21 non-null     float64
#  3   debt_folios_crore    21 non-null     float64
#  4   hybrid_folios_crore  21 non-null     float64
#  5   others_folios_crore  21 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.1+ KB

# %%
df_6
# Out:
#       month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0   2022-01               13.26                 9.28               1.86
# 1   2022-04               13.91                 9.74               1.95
# 2   2022-07               13.85                 9.69               1.94
# 3   2022-10               14.12                 9.88               1.98
# 4   2023-01               14.81                10.37               2.07
# 5   2023-04               15.54                10.88               2.18
# 6   2023-07               16.28                11.40               2.28
# 7   2023-10               16.72                11.70               2.34
# 8   2024-01               17.78                12.45               2.49
# 9   2024-04               18.85                13.20               2.64
# 10  2024-07               19.98                13.99               2.80
# 11  2024-10               21.62                15.13               3.03
# ...

# %%
df_9['portfolio_date'] = pd.to_datetime(df_9['portfolio_date'], format='%Y-%m-%d')

# %%
df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8050 entries, 0 to 8049
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         8050 non-null   object
#  1   index_name   8050 non-null   object
#  2   close_value  8050 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 188.8+ KB

# %%
df_10['date'] = pd.to_datetime(df_10['date'], format='%Y-%m-%d')

# %%
df_1.shape, df_2.shape, df_3.shape, df_4.shape, df_5.shape, df_6.shape, df_7.shape, df_8.shape, df_9.shape, df_10.shape
# Out:
# ((40, 15),
#  (46000, 3),
#  (90, 5),
#  (48, 6),
#  (144, 3),
#  (21, 6),
#  (40, 19),
#  (32778, 15),
#  (322, 8),
#  (8050, 3))

# %%
df_2
# Out:
#        amfi_code       date       nav
# 5750      100016 2022-01-03  520.4608
# 10350     100025 2022-01-03   26.3169
# 8050      100033 2022-01-03  107.3758
# 32200     101206 2022-01-03  305.0996
# 33350     101207 2022-01-03   38.5736
# ...          ...        ...       ...
# 41399     148568 2026-05-29  205.4510
# 42549     148569 2026-05-29   97.7435
# 43699     149322 2026-05-29  606.2349
# 44849     149323 2026-05-29  245.3651
# 45999     149324 2026-05-29  279.7511
#
# [46000 rows x 3 columns]

# %%
df_2['daily_return'] = df_2.groupby('amfi_code')['nav'].pct_change()

# %%
df_2
# Out:
#        amfi_code       date       nav  daily_return
# 5750      100016 2022-01-03  520.4608           NaN
# 10350     100025 2022-01-03   26.3169           NaN
# 8050      100033 2022-01-03  107.3758           NaN
# 32200     101206 2022-01-03  305.0996           NaN
# 33350     101207 2022-01-03   38.5736           NaN
# ...          ...        ...       ...           ...
# 41399     148568 2026-05-29  205.4510      0.011354
# 42549     148569 2026-05-29   97.7435      0.016042
# 43699     149322 2026-05-29  606.2349      0.002064
# 44849     149323 2026-05-29  245.3651     -0.002778
# 45999     149324 2026-05-29  279.7511     -0.003335
#
# [46000 rows x 4 columns]

# %%
df_2.fillna(0, inplace=True)

# %%
df_2
# Out:
#        amfi_code       date       nav  daily_return
# 5750      100016 2022-01-03  520.4608      0.000000
# 10350     100025 2022-01-03   26.3169      0.000000
# 8050      100033 2022-01-03  107.3758      0.000000
# 32200     101206 2022-01-03  305.0996      0.000000
# 33350     101207 2022-01-03   38.5736      0.000000
# ...          ...        ...       ...           ...
# 41399     148568 2026-05-29  205.4510      0.011354
# 42549     148569 2026-05-29   97.7435      0.016042
# 43699     149322 2026-05-29  606.2349      0.002064
# 44849     149323 2026-05-29  245.3651     -0.002778
# 45999     149324 2026-05-29  279.7511     -0.003335
#
# [46000 rows x 4 columns]

# %%
df_2[df_2['amfi_code']==100016]
# Out:
#       amfi_code       date       nav  daily_return
# 5750     100016 2022-01-03  520.4608      0.000000
# 5751     100016 2022-01-04  515.0971     -0.010306
# 5752     100016 2022-01-05  521.7239      0.012865
# 5753     100016 2022-01-06  515.7880     -0.011377
# 5754     100016 2022-01-07  515.1639     -0.001210
# ...         ...        ...       ...           ...
# 6895     100016 2026-05-25  599.9335     -0.004227
# 6896     100016 2026-05-26  596.4426     -0.005819
# 6897     100016 2026-05-27  590.8555     -0.009367
# 6898     100016 2026-05-28  590.9452      0.000152
# 6899     100016 2026-05-29  583.6113     -0.012410
#
# [1150 rows x 4 columns]

# %%
from pathlib import Path
project_root = Path.cwd()
if not (project_root / 'data').exists():
    project_root = project_root.parent
file_path_new = str(project_root / 'data' / 'processed') + '/'

# %%
df_1.to_csv(file_path_new + "01_fund_master.csv", index=False)
df_2.to_csv(file_path_new + "02_nav_history.csv", index=False)
df_3.to_csv(file_path_new + "03_aum_by_fund_house.csv", index=False)
df_4.to_csv(file_path_new + "04_monthly_sip_inflows.csv", index=False)
df_5.to_csv(file_path_new + "05_category_inflows.csv", index=False)
df_6.to_csv(file_path_new + "06_industry_folio_count.csv", index=False)
df_7.to_csv(file_path_new + "07_scheme_performance.csv", index=False)
df_8.to_csv(file_path_new + "08_investor_transactions.csv", index=False)
df_9.to_csv(file_path_new + "09_portfolio_holdings.csv", index=False)
df_10.to_csv(file_path_new + "10_benchmark_indices.csv", index=False)
